# %%
# %matplotlib inline
# %time from hikyuu.interactive import *
# Out:
# 2025-11-04 10:32:19,793 [INFO] runing in interactive session [<module>] (F:\anaconda\envs\hikyuu_hub\Lib\site-packages\hikyuu\__init__.py:131) [hikyuu::hku_info]
# 2025-11-04 10:32:19,793 [INFO] running in jupyter [<module>] (F:\anaconda\envs\hikyuu_hub\Lib\site-packages\hikyuu\__init__.py:138) [hikyuu::hku_info]
# 2025-11-04 10:32:19.800 [HKU-I] - Plugin path: F:\anaconda\envs\hikyuu_hub\Lib\site-packages\hikyuu\plugin (StockManager.cpp:113)
# 2025-11-04 10:32:19.974 [HKU-I] - Using SQLITE3 BaseInfoDriver (BaseInfoDriver.cpp:57)
# 2025-11-04 10:32:19.976 [HKU-I] - 加载市场信息…… (StockManager.cpp:704)
# 2025-11-04 10:32:19.978 [HKU-I] - 加载证券类型信息…… (StockManager.cpp:722)
# 2025-11-04 10:32:19.979 [HKU-I] - 加载证券信息…… (StockManager.cpp:602)
# 2025-11-04 10:32:20.109 [HKU-I] - 加载权息数据…… (StockManager.cpp:740)
# 2025-11-04 10:32:20.302 [HKU-I] - 加载板块信息…… (StockManager.cpp:182)
# 2025-11-04 10:32:20.581 [HKU-I] - 加载K线数据…… (StockManager.cpp:186)
# ...

# %%
bind_email("lijiawei.shin@foxmail.com", "5238f5f3-61eb-4c68-853b-a0fe1712c1d2")
# Out:
# Bind success!

# %%
active_device("5238f5f3-61eb-4c68-853b-a0fe1712c1d2")
# Out:
# active result: License verification was successful

# %%
view_license()
# Out:
# 'Subscription authorization\n  expiration time: 2025-12-02 12:28:17\n  authorized user: lijiawei.shin@foxmail.com\n  verification status: License verification was successful\n'

# %%
update_hub("dev")

# %%
remove_hub("dev")

# %%
sys = get_part("default.sys.趋势双均线")

# %%
sys
# Out:
# System{
#   default.sys.趋势双均线,
#   KQuery(0, 9223372036854775807, INDEX, DAY, NO_RECOVER),
#   Stock(, , , , 0, +infinity, +infinity),
#   params[buy_delay(bool): 1, can_trade_when_high_eq_low(bool): 0, cn_open_position(bool): 0, delay_use_current_price(bool): 1, ev_open_position(bool): 0, ignore_sell_sg(bool): 0, max_delay_count(int): 3, sell_delay(bool): 1, shared_cn(bool): 0, shared_ev(bool): 1, shared_mm(bool): 0, shared_pg(bool): 0, shared_sg(bool): 0, shared_sp(bool): 0, shared_st(bool): 0, shared_tm(bool): 0, shared_tp(bool): 0, support_borrow_cash(bool): 0, support_borrow_stock(bool): 0, tp_delay_n(int): 1, tp_monotonic(bool): 1, trace(bool): 0, ],
#   Environment(NULL),
#   Condition(NULL),
#   MoneyManager(MM_Nothing, params[auto-checkin(bool): 0, disable_cn_force_clean_position(bool): 0, disable_ev_force_clean_position(bool): 0, if_have_a_position_will_not_buy(bool): 0, max-stock(int): 20000, ]),
# ...

# %%
sys = get_part("default.sys.趋势双均线")
sys
# Out:
# System{
#   default.sys.趋势双均线,
#   KQuery(0, 9223372036854775807, INDEX, DAY, NO_RECOVER),
#   Stock(, , , , 0, +infinity, +infinity),
#   params[buy_delay(bool): 1, can_trade_when_high_eq_low(bool): 0, cn_open_position(bool): 0, delay_use_current_price(bool): 1, ev_open_position(bool): 0, ignore_sell_sg(bool): 0, max_delay_count(int): 3, sell_delay(bool): 1, shared_cn(bool): 0, shared_ev(bool): 1, shared_mm(bool): 0, shared_pg(bool): 0, shared_sg(bool): 0, shared_sp(bool): 0, shared_st(bool): 0, shared_tm(bool): 0, shared_tp(bool): 0, support_borrow_cash(bool): 0, support_borrow_stock(bool): 0, tp_delay_n(int): 1, tp_monotonic(bool): 1, trace(bool): 0, ],
#   Environment(NULL),
#   Condition(NULL),
#   MoneyManager(MM_Nothing, params[auto-checkin(bool): 0, disable_cn_force_clean_position(bool): 0, disable_ev_force_clean_position(bool): 0, if_have_a_position_will_not_buy(bool): 0, max-stock(int): 20000, ]),
# ...

# %%
get_hub_path("default")
# Out:
# 'C:\\Users\\Administrator/.hikyuu/hub_cache/default'

# %%
get_hub_name_list()
# Out:
# ['default']

# %%
remove_hub("dev2")
add_local_hub("dev", 'D:\\stock\\hikyuu_hub_fork\\hikyuu_hub')

# %%
get_part_name_list('dev')
# Out:
# ['dev.af.equal_weight',
#  'dev.af.fixed_weight',
#  'dev.cn.ama',
#  'dev.cn.ema',
#  'dev.cn.ma',
#  'dev.ev.ama',
#  'dev.ev.ema',
#  'dev.ev.ma',
#  'dev.mm.fixed_capital',
#  'dev.mm.fixed_count',
#  'dev.mm.fixed_percent',
#  'dev.mm.fixed_risk',
#  'dev.mm.fixed_unit',
#  'dev.mm.noting',
#  'dev.mm.williams_fixed_risk',
#  'dev.pg.fixed_hold_days',
#  'dev.pg.fixed_percent',
#  'dev.pg.nogoal',
#  'dev.se.fixed',
#  'dev.se.signal',
#  'dev.se.最低单因子',
#  'dev.se.最低市净率',
#  'dev.sg.ama',
#  'dev.sg.买入双均线金叉',
#  'dev.sg.买入布林线回踩中轨',
#  'dev.sg.买入布林线挤压',
#  'dev.sg.买入收盘价突破布林线上轨',
#  'dev.sg.卖出双均线死叉',
#  'dev.sg.卖出收盘价跌破布林线下轨',
#  'dev.sg.卖出收盘价连续N日低于布林线中轨',
#  'dev.sg.卖出触及布林线中轨并反转',
#  'dev.sg.趋势布林带',
#  'dev.sp.fixed_percent',
#  'dev.sp.fixed_value',
#  'dev.st.fixed_percent',
#  'dev.st.saftyloss',
#  'dev.pf.base_最低单因子轮动',
#  'dev.pf.银行股低市净率轮动',
#  'dev.sys.ama_fixed_count',
#  'dev.sys.emv择时',
#  'dev.sys.双均线金叉',
#  'dev.sys.布林线回踩策略1',
#  'dev.sys.布林线回踩策略2',
# ...

# %%
# emv = get_part("dev.ind.emv")

emv = get_part("dev.ind.通达信百变一阳指")

s = sm['sh688981']
# 
k = s.get_kdata(Query(-100))
k.plot()

c = emv(k)
print(c)
c.plot(legend_on=True)
# Out:
# Indicator{
#   name: dev.ind.通达信百变一阳指
#   size: 100
#   discard: 3
#   result sets: 1
#   params: params[kdata(KData): SH688981, ]
#   support indicator param: False
# ...

# %%
help(ax_set_locator_formatter)
# Out:
# Help on function ax_set_locator_formatter in module hikyuu.draw.drawplot:
#
# ax_set_locator_formatter(axes, dates, typ)
#     设置指定坐标轴的日期显示，根据指定的K线类型优化X轴坐标显示
#
#     :param axes: 指定的坐标轴
#     :param dates: Datetime构成可迭代序列
#     :param Query.KType typ: K线类型

# %%
help(ALIGN)
# Out:
# Help on built-in function ALIGN in module hikyuu.cpp.core312:
#
# ALIGN(...) method of pybind11_builtins.pybind11_detail_function_record_v1_msvc_md_mscver19 instance
#     ALIGN(*args, **kwargs)
#     Overloaded function.
#
#     1. ALIGN(ref: hikyuu.cpp.core312.DatetimeList, fill_null: bool = True) -> hikyuu.cpp.core312.Indicator
#
#     2. ALIGN(data: hikyuu.cpp.core312.Indicator, ref: hikyuu.cpp.core312.DatetimeList, fill_null: bool = True) -> hikyuu.cpp.core312.Indicator
#
#     3. ALIGN(data: hikyuu.cpp.core312.Indicator, ref: hikyuu.cpp.core312.Indicator, fill_null: bool = True) -> hikyuu.cpp.core312.Indicator
#
#     4. ALIGN(data: hikyuu.cpp.core312.Indicator, ref: hikyuu.cpp.core312.KData, fill_null: bool = True) -> hikyuu.cpp.core312.Indicator
#
#     ALIGN(data, ref):
#
#         按指定的参考日期对齐
#
#         :param Indicator data: 输入数据
#         :param DatetimeList|Indicator|KData ref: 指定做为日期参考的 DatetimeList、Indicator 或 KData
# ...

# %%
import akshare as ak
df = ak.bond_zh_us_rate("20221219")
x = df_to_ind(df, '美国国债收益率10年', '日期')
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]

# %%
start = Datetime(20251008)
end = Datetime(20251103)

td = end - start
start + Days(10)
# Out:
# Datetime(2025,10,18,0,0,0,0,0)

# %%
print(EMA())
help(ALIGN)
# Out:
# Indicator{
#   name: EMA
#   size: 0
#   discard: 0
#   result sets: 1
#   params: params[kdata(KData): Null, n(int): 22, ]
#   support indicator param: True
#   ind params: {}
#   formula: EMA
#   values0: []
# }
# Help on built-in function ALIGN in module hikyuu.cpp.core312:
#
# ALIGN(...) method of pybind11_builtins.pybind11_detail_function_record_v1_msvc_md_mscver19 instance
#     ALIGN(*args, **kwargs)
#     Overloaded function.
#
#     1. ALIGN(ref: hikyuu.cpp.core312.DatetimeList, fill_null: bool = True) -> hikyuu.cpp.core312.Indicator
#
#     2. ALIGN(data: hikyuu.cpp.core312.Indicator, ref: hikyuu.cpp.core312.DatetimeList, fill_null: bool = True) -> hikyuu.cpp.core312.Indicator
#
#     3. ALIGN(data: hikyuu.cpp.core312.Indicator, ref: hikyuu.cpp.core312.Indicator, fill_null: bool = True) -> hikyuu.cpp.core312.Indicator
#
#     4. ALIGN(data: hikyuu.cpp.core312.Indicator, ref: hikyuu.cpp.core312.KData, fill_null: bool = True) -> hikyuu.cpp.core312.Indicator
#
# ...

# %%
print(CVAL())
help(df_to_ind)
help(concat_to_df)
# Out:
# Indicator{
#   name: CVAL
#   size: 1
#   discard: 0
#   result sets: 1
#   params: params[discard(int): 0, kdata(KData): Null, value(double): 0, ]
#   support indicator param: False
#   formula: CVAL
#   values0: [0]
# }
# Help on function df_to_ind in module hikyuu.indicator.indicator:
#
# df_to_ind(df, col_name, col_date=None)
#     将 pandas.DataFrame 指定列转化为 Indicator
#
#     示例，从 akshare 获取美国国债10年期收益率:
#
#         import akshare as ak
#         df = ak.bond_zh_us_rate("19901219")
#         x = df_to_ind(df, '美国国债收益率10年', '日期')
#
#     :param df: pandas.DataFrame
#     :param col_name: 指定列名
#     :param col_date: 指定日期列名 (为None时忽略, 否则该列为对应参考日期)
#     :return: Indicator
#
# Help on function concat_to_df in module hikyuu.indicator.indicator:
#
# concat_to_df(dates, ind_list, head_stock_code=True, head_ind_name=False)
#     将列表中的指标至合并在一张 pandas DataFrame 中
#
#     :param DatetimeList dates: 指定的日期列表
#     :param sequence ind_list: 已计算的指标列表
#     :param bool head_ind_name: 表标题是否使用指标名称
# ...
